# %% [markdown]
# <a href="https://colab.research.google.com/github/manola1109/Model-Deployment/blob/main/Deploying_rule_based_model_using_Streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Deploying the rule based model to automate loan prediction
#
# 1. Building the Frontend of the application
# 2. Loading the data
# 3. Building the model to automate Loan Eligibility
# 4. Deploying the application

# %% [markdown]
# ## 1. Building the Frontend of the application
#
# 1.1 Install Required Libraries<br>
# 1.2 Creating the Frontend of the app using Streamlit
#
# ### 1.1 Install Required Libraries

# %%
# installing pyngrok
# !pip install -q pyngrok

# %%
# installing streamlit
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 83.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 94.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.1 MB/s eta 0:00:00

# %%
# !streamlit version
# Out:
# Streamlit, version 1.46.0

# %% [markdown]
# ### 1.2 Creating the frontend of the app using streamlit

# %%
# creating the script
# %%writefile app.py

# importing streamlit
import streamlit as st

# this is the main function in which we define our app
def main():
    # header of the page
    st.markdown("Check your Loan Eligibility")

    # 2. Loading the data

    # following lines create boxes in which user can enter data required to make prediction
    Gender = st.selectbox('Gender',("Male","Female","Other"))
    Married = st.selectbox('Marital Status',("Unmarried","Married","Other"))
    ApplicantIncome = st.number_input("Monthly Income in Rupees")
    LoanAmount = st.number_input("Loan Amount in Rupees")
    result =""

    # when 'Check' is clicked, make the prediction and store it
    if st.button("Check"):
        result = prediction(Gender, Married, ApplicantIncome, LoanAmount)
        st.success('Your loan is {}'.format(result))

# defining the function which will make the prediction using the data which the user inputs
def prediction(Gender, Married, ApplicantIncome, LoanAmount):

    # 3. Building the model to automate Loan Eligibility
    if (ApplicantIncome >= 100):
        loan_status = 'Approved'
    elif (LoanAmount < 100):
        loan_status = 'Approved'
    else:
        loan_status = 'Rejected'
    return loan_status

if __name__=='__main__':
    main()
# Out:
# Writing app.py

# %% [markdown]
# ## 4. Deploying the application

# %%
# running the app
# !streamlit run app.py &>/dev/null&

# %%
# making the locally-hosted web application to be publicly accessible
from pyngrok import ngrok

# Replace 'YOUR_AUTHTOKEN' with your actual ngrok authtoken
ngrok.set_auth_token("ngrok")

public_url = ngrok.connect('8501')
public_url
# Out:
# <NgrokTunnel: "https://7c1c-34-126-130-29.ngrok-free.app" -> "http://localhost:8501">
